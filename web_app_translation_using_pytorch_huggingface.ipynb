# %% [markdown]
# #1. Simple Web App Translation

# %%
# !pip3 install torch==1.10.2+cu113 torchvision==0.11.3+cu113 torchaudio===0.10.2+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/cu113/torch_stable.html
# ...
#      |██████████████▋                 | 834.1 MB 1.3 MB/s eta 0:12:48tcmalloc: large alloc 1147494400 bytes == 0x5640354ac000 @  0x7f064b85e615 0x563ffb8753bc 0x563ffb95618a 0x563ffb8781cd 0x563ffb96ab3d 0x563ffb8ec458 0x563ffb8e702f 0x563ffb879aba 0x563ffb8ec2c0 0x563ffb8e702f 0x563ffb879aba 0x563ffb8e8cd4 0x563ffb96b986 0x563ffb8e8350 0x563ffb96b986 0x563ffb8e8350 0x563ffb96b986 0x563ffb8e8350 0x563ffb879f19 0x563ffb8bda79 0x563ffb878b32 0x563ffb8ec1dd 0x563ffb8e702f 0x563ffb879aba 0x563ffb8e8cd4 0x563ffb8e702f 0x563ffb879aba 0x563ffb8e7eae 0x563ffb8799da 0x563ffb8e8108 0x563ffb8e702f
# ...

# %%
# !pip install transformers ipywidgets gradio --upgrade
# Out:
# ...
#      |████████████████████████████████| 3.5 MB 11.3 MB/s
# ...
#      |████████████████████████████████| 5.7 MB 60.8 MB/s
# ...
#      |████████████████████████████████| 6.8 MB 54.7 MB/s
# ...
#      |████████████████████████████████| 67 kB 5.0 MB/s
# ...
#      |████████████████████████████████| 596 kB 66.5 MB/s
# ...
#      |████████████████████████████████| 895 kB 57.2 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 48.2 MB/s
# ...
#      |████████████████████████████████| 84 kB 2.4 MB/s
# ...
#      |████████████████████████████████| 53 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 53 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 210 kB 60.0 MB/s
# ...
#      |████████████████████████████████| 2.0 MB 44.1 MB/s
# ...
#      |████████████████████████████████| 94 kB 3.0 MB/s
# ...
#      |████████████████████████████████| 144 kB 62.4 MB/s
# ...
#      |████████████████████████████████| 271 kB 60.2 MB/s
# ...
#      |████████████████████████████████| 58 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 10.9 MB 50.7 MB/s
# ...

# %%
import gradio as gr
from transformers import pipeline

# %% [markdown]
# # 2. Load up pipeline

# %%
translation_pipeline = pipeline('translation_en_to_de')
# Out:
# No model was supplied, defaulted to t5-base (https://huggingface.co/t5-base)
# Downloading:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/850M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.32M [00:00<?, ?B/s]

# %%
translation_pipeline('I love ice cream')
# Out:
# [{'translation_text': 'Ich liebe Eiscreme'}]

# %% [markdown]
# #3. Create Gradio Function and Interface

# %%
def translate_transformers(from_text):
  results = translation_pipeline(from_text)
  return results[0]['translation_text']

# %%
translate_transformers('My name is Asyraf')
# Out:
# 'Mein Name ist Asyraf'

# %%
# Create gradio UI

interface = gr.Interface(fn=translate_transformers, inputs=gr.inputs.Textbox(lines=2, placeholder='Text to Translate'), 
                         outputs='text')
interface.launch()
# Out:
# Colab notebook detected. To show errors in colab notebook, set `debug=True` in `launch()`
# Running on public URL: https://29429.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces (https://huggingface.co/spaces)
#         <iframe
#             width="900"
#             height="500"
#             src="https://29429.gradio.app"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# (<fastapi.applications.FastAPI at 0x7f182ad28b50>,
#  'http://127.0.0.1:7860/',
#  'https://29429.gradio.app')
